# %%
import qutip
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
b=qutip.Bloch()

# %%
b.make_sphere()

# %%
pnt = [1/np.sqrt(3), 1/np.sqrt(3), 1/np.sqrt(3)]
b.add_points(pnt)
b.render()

# %%
b = qutip.Bloch()
pnt = [1./np.sqrt(3), 1./np.sqrt(3), 1./np.sqrt(3)]
b.add_points(pnt)
vec = [0, 1, 0]
b.add_vectors(vec)
up = qutip.basis(2, 0)
b.add_states(up)
b.render()
b.show()

# %%
c=qutip.Bloch3d()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/qutip-env/lib/python3.11/site-packages/qutip/bloch3d.py:80, in Bloch3d.__init__(self, fig)
#      79 try:
# ---> 80     from mayavi import mlab
#      81 except:
#
# ModuleNotFoundError: No module named 'mayavi'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 c=qutip.Bloch3d()
#
# File ~/anaconda3/envs/qutip-env/lib/python3.11/site-packages/qutip/bloch3d.py:82, in Bloch3d.__init__(self, fig)
#      80     from mayavi import mlab
#      81 except:
# ---> 82     raise Exception("This function requires the mayavi module.")
#      84 # ---Image options---
#      85 self.fig = None
#
# Exception: This function requires the mayavi module.
